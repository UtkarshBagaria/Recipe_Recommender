# %%
import pandas as pd
df1=pd.read_csv('Working_file.csv')
df1.head()
# Out:
#                                 TranslatedRecipeName  \
# 0                               Masala Karela Recipe
# 1                         Spicy Tomato Rice (Recipe)
# 2  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4  Andhra Style Alam Pachadi Recipe - Adrak Chutn...
#
#                                TranslatedIngredients  PrepTimeInMins  \
# 0                            karela,ram flour,amchur              15
# 1  rice,bc belle bhat powder,chickpea lentils,whi...               5
# 2  white urad dal,hee,spricurry leaves,lemon juic...              20
# 3  chicken,aram masala powder,sesame,methi seeds,...              15
# 4  chana dal,white urad dal,red chillies,coriande...              10
#
#    CookTimeInMins  TotalTimeInMins  Servings               Cuisine  \
# 0              30               45         6                Indian
# 1              10               15         3  South Indian Recipes
# ...

# %%
import re
for index,data in df1['TranslatedInstructions'].iteritems():
    data= data.strip()
    # Remove extra whitespaces between words
    data = re.sub(r'\s+', ' ', data)
    # Find the index of the second last period or exclamation mark
    # Find all occurrences of periods and exclamation marks
    c=0
    for i in range(len(data)-1,-1,-1):
        if(data[i]=='!' or data[i]=='.'):
            c+=1
        if(c==2):
            print((data[i+1:]).strip())
            break
# Out:
# Serve Masala Karela along with Panchmel Dal and Phulka for a weekday meal with your family.
# Serve tomato puliogre with tomato cucumber raita and papad for dinner.
# Mix well and serve along with Coconut Chutney and a hot cup of coffee or tea for a wholesome breakfast.
# Serve Gongura Chicken with Ghee Rice Recipe | Neychoru , Tomato Onion Cucumber Raita Recipe and a Semiya Payasam for a delicious weekend lunch.
# Serve Andhra Style Alam Pachadi with Ghee Roast Dosa and Kirai Sambar for breakfast.
# Add in the tadka over it and Serve the Pudina Khara Pongal Recipe along with Kathirikai Gothsu Recipe (Spicy and Tangy Eggplant Curry)and South Indian Coconut Chutney for a relaxed weekend breakfast.
# Serve the Udupi Style Ash Gourd Coconut Curry Recipe along with steamed rice, Elai Vadam and Pisarna Manga for lunch.
# ...

# %%
import openai

openai.api_key = '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'

completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo", 
  messages=[{"role": "user", "content": "What is the OpenAI mission?"}]
)

print(completion)
# Out:
# {
#   "id": "chatcmpl-7YA0WH8XRlzENUUlC1C0lXc9NYSc0",
#   "object": "chat.completion",
#   "created": 1688375976,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "The OpenAI mission is to ensure that artificial general intelligence (AGI), which refers to highly autonomous systems that outperform humans in most economically valuable work, benefits all of humanity. OpenAI aims to directly build safe and beneficial AGI, but if another project that aligns with its values comes close to building AGI before it does, OpenAI commits to stop competing with and start assisting that project to ensure safety and efficacy. The organization also emphasizes cooperation with other research and policy institutions to create a global community that addresses AGI's global challenges.\n"
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 14,
# ...

# %%
completion.choices[0].message['content']
# Out:
# "The OpenAI mission is to ensure that artificial general intelligence (AGI), which refers to highly autonomous systems that outperform humans in most economically valuable work, benefits all of humanity. OpenAI aims to directly build safe and beneficial AGI, but if another project that aligns with its values comes close to building AGI before it does, OpenAI commits to stop competing with and start assisting that project to ensure safety and efficacy. The organization also emphasizes cooperation with other research and policy institutions to create a global community that addresses AGI's global challenges.\n"

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline

model_name = "deepset/roberta-base-squad2"

# a) Get predictions
nlp = pipeline('question-answering', model=model_name, tokenizer=model_name)
QA_input = {
    'question': 'What is the dish?',
    'context': 'Serve this Chettinad Style Chicken Roast Recipe on its own as a party starter or with Kerala Style Appam Recipe (Without Yeast) or Mangalorean Neer Dosa Recipe (Savory Rice & Coconut Crepe) for a complete meal.'
}
res = nlp(QA_input)

# b) Load model & tokenizer
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
print(res)
# Out:
# {'score': 0.6057016849517822, 'start': 11, 'end': 47, 'answer': 'Chettinad Style Chicken Roast Recipe'}
