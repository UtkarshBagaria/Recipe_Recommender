# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Reading the datasets

# %%
# reading the dataset
df1 = pd.read_csv('6000 Recipes\IndianFoodDatasetCSV.csv')
# df1

# %%
# df1.describe()

# %% [markdown]
# ## Data Cleaning and Preprocessing along with EDA

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6239 entries, 0 to 6238
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   TranslatedRecipeName    6239 non-null   object
#  1   TranslatedIngredients   6237 non-null   object
#  2   PrepTimeInMins          6239 non-null   int64
#  3   CookTimeInMins          6239 non-null   int64
#  4   TotalTimeInMins         6239 non-null   int64
#  5   Servings                6239 non-null   int64
#  6   Cuisine                 6239 non-null   object
#  7   Course                  6239 non-null   object
#  8   Diet                    6239 non-null   object
#  9   Instructions            6239 non-null   object
#  10  TranslatedInstructions  6239 non-null   object
#  11  URL                     6239 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 585.0+ KB

# %%
df1.isnull().sum()
# Out:
# Srno                      0
# RecipeName                0
# TranslatedRecipeName      0
# Ingredients               6
# TranslatedIngredients     6
# PrepTimeInMins            0
# CookTimeInMins            0
# TotalTimeInMins           0
# Servings                  0
# Cuisine                   0
# Course                    0
# Diet                      0
# Instructions              0
# TranslatedInstructions    0
# URL                       0
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1.drop(['RecipeName','Ingredients','Instructions'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#    Srno                               TranslatedRecipeName  \
# 0     1                               Masala Karela Recipe
# 1     2                         Spicy Tomato Rice (Recipe)
# 2     3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3     4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4     5  Andhra Style Alam Pachadi Recipe - Adrak Chutn...
#
#                                TranslatedIngredients  PrepTimeInMins  \
# 0  6 Karela (Bitter Gourd/ Pavakkai) - deseeded,S...              15
# 1  2-1 / 2 cups rice - cooked, 3 tomatoes, 3 teas...               5
# 2  1-1/2 cups Rice Vermicelli Noodles (Thin),1 On...              20
# 3  500 grams Chicken,2 Onion - chopped,1 Tomato -...              15
# 4  1 tablespoon chana dal, 1 tablespoon white ura...              10
#
#    CookTimeInMins  TotalTimeInMins  Servings               Cuisine  \
# 0              30               45         6                Indian
# ...

# %%
df1['Cuisine'].value_counts()
# Out:
# Indian                  1157
# Continental             1020
# North Indian Recipes     936
# South Indian Recipes     681
# Italian Recipes          235
#                         ...
# Jewish                     1
# Dessert                    1
# Side Dish                  1
# Shandong                   1
# Lunch                      1
# Name: Cuisine, Length: 82, dtype: int64

# %%
df1['Course'].value_counts()
# Out:
# Lunch                           1763
# Side Dish                        992
# Snack                            876
# Dinner                           781
# Dessert                          659
# Appetizer                        637
# Main Course                      315
# South Indian Breakfast           260
# World Breakfast                  260
# North Indian Breakfast           122
# Indian Breakfast                 101
# Vegetarian                        47
# One Pot Dish                      33
# High Protein Vegetarian            7
# Brunch                             4
# Vegan                              3
# Non Vegeterian                     2
# Eggetarian                         1
# No Onion No Garlic (Sattvic)       1
# Sugar Free Diet                    1
# Name: Course, dtype: int64

# %%
df1['Diet'].value_counts()
# Out:
# Vegetarian                      4706
# High Protein Vegetarian          705
# Non Vegeterian                   427
# Eggetarian                       344
# Diabetic Friendly                260
# High Protein Non Vegetarian      225
# No Onion No Garlic (Sattvic)      73
# Vegan                             61
# Gluten Free                       50
# Sugar Free Diet                   14
# Name: Diet, dtype: int64

# %%
df1['PrepTimeInMins'].value_counts()
# Out:
# 10     2806
# 15     1230
# 20     1071
# 5       431
# 30      421
#        ...
# 630       1
# 105       1
# 4         1
# 18        1
# 1         1
# Name: PrepTimeInMins, Length: 86, dtype: int64

# %%
df1['CookTimeInMins'].value_counts()
# Out:
# 30     1676
# 20     1189
# 15      733
# 45      557
# 40      521
#        ...
# 17        1
# 780       1
# 225       1
# 600       1
# 38        1
# Name: CookTimeInMins, Length: 67, dtype: int64

# %%
df1['TotalTimeInMins'].value_counts()
# Out:
# 40     975
# 30     844
# 50     672
# 35     565
# 45     517
#       ...
# 79       1
# 67       1
# 455      1
# 89       1
# 58       1
# Name: TotalTimeInMins, Length: 167, dtype: int64

# %% [markdown]
# ## Ingredients

# %%
df1['TranslatedIngredients'][0]
# Out:
# '6 Karela (Bitter Gourd/ Pavakkai) - deseeded,Salt - to taste,1 Onion - thinly sliced,3 tablespoon Gram flour (besan),2 teaspoons Turmeric powder (Haldi),1 tablespoon Red Chilli powder,2 teaspoons Cumin seeds (Jeera),1 tablespoon Coriander Powder (Dhania),1 tablespoon Amchur (Dry Mango Powder),Sunflower Oil - as required'

# %%
for index, data in df1['TranslatedIngredients'].iteritems():
    # Modify the value
    data = data.strip()

    # Remove newlines and tabs
    data = data.replace('\n', '').replace('\t', '')

    # Remove extra spaces
    data = ' '.join(data.split())

    # Split the data by commas
    ingredients = data.split(',')

    # Remove leading and trailing whitespaces from each ingredient
    ingredients = [ingredient.strip() for ingredient in ingredients]

    df1.at[index, 'TranslatedIngredients'] = ingredients
df1['TranslatedIngredients'].head()
# Out:
# 0    [6 Karela (Bitter Gourd/ Pavakkai) - deseeded,...
# 1    [2-1 / 2 cups rice - cooked, 3 tomatoes, 3 tea...
# 2    [1-1/2 cups Rice Vermicelli Noodles (Thin), 1 ...
# 3    [500 grams Chicken, 2 Onion - chopped, 1 Tomat...
# 4    [1 tablespoon chana dal, 1 tablespoon white ur...
# Name: TranslatedIngredients, dtype: object

# %%
df1['TranslatedIngredients'][0]
# Out:
# ['6 Karela (Bitter Gourd/ Pavakkai) - deseeded',
#  'Salt - to taste',
#  '1 Onion - thinly sliced',
#  '3 tablespoon Gram flour (besan)',
#  '2 teaspoons Turmeric powder (Haldi)',
#  '1 tablespoon Red Chilli powder',
#  '2 teaspoons Cumin seeds (Jeera)',
#  '1 tablespoon Coriander Powder (Dhania)',
#  '1 tablespoon Amchur (Dry Mango Powder)',
#  'Sunflower Oil - as required']

# %%
df1['Diet'][3]
# Out:
# 'Non Vegeterian'

# %%
df1
# Out:
#        Srno                               TranslatedRecipeName  \
# 0         1                               Masala Karela Recipe
# 1         2                         Spicy Tomato Rice (Recipe)
# 2         3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3         4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4         5  Andhra Style Alam Pachadi Recipe - Adrak Chutn...
# ...     ...                                                ...
# 6866  14073                        Goan Mushroom Xacuti Recipe
# 6867  14107        Sweet Potato & Methi Stuffed Paratha Recipe
# 6868  14165      Ullikadala Pulusu Recipe | Spring Onion Curry
# 6869  14167  Kashmiri Style Kokur Yakhni Recipe-Chicken Coo...
# 6870  14211                                 Navrang Dal Recipe
#
#                                   TranslatedIngredients  PrepTimeInMins  \
# 0     [6 Karela (Bitter Gourd/ Pavakkai) - deseeded,...              15
# ...

# %%
df1['TranslatedIngredients'][1]
# Out:
# ['2-1 / 2 cups rice - cooked',
#  '3 tomatoes',
#  '3 teaspoons BC Belle Bhat powder',
#  'salt - as per taste',
#  '1 teaspoon chickpea lentils',
#  '1/2 teaspoon cumin seeds',
#  '1 teaspoon white urad dal',
#  '1/2 Teaspoon mustard',
#  '1 green chilli',
#  '1 dry red chilli',
#  '2 teaspoon cashew - or peanuts',
#  '1-1 / 2 tablespoon oil - 1/2 teaspoon asafoetida']

# %%
import re

def is_english(text):
    english_pattern = re.compile(r'^[A-Za-z0-9.,!?;:(){}\[\]<>@#$%^&*_+=\-|\\/~`"\'£€¥₹₽\s]*$')
    return bool(re.match(english_pattern, text))

# %%
for index, data in df1['TranslatedIngredients'].iteritems():
    for d in data:
        if(is_english(d)==False):
            df1.drop(index,inplace=True)
            break

# %%
for index, data in df1['TranslatedInstructions'].iteritems():
    for d in data:
        if(is_english(d)==False):
            df1.drop(index,inplace=True)
            break

# %%
df1
# Out:
#        Srno                               TranslatedRecipeName  \
# 0         1                               Masala Karela Recipe
# 1         2                         Spicy Tomato Rice (Recipe)
# 2         3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3         4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4         5  Andhra Style Alam Pachadi Recipe - Adrak Chutn...
# ...     ...                                                ...
# 6863  14030                         Saffron Paneer Peda Recipe
# 6864  14038  Italian Arancini Rice Balls Recipe With Delici...
# 6865  14045        Quinoa Phirnee Recipe (Quinoa Milk Pudding)
# 6868  14165      Ullikadala Pulusu Recipe | Spring Onion Curry
# 6869  14167  Kashmiri Style Kokur Yakhni Recipe-Chicken Coo...
#
#                                   TranslatedIngredients  PrepTimeInMins  \
# 0     [6 Karela (Bitter Gourd/ Pavakkai) - deseeded,...              15
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

def remove_adjectives_verbs_adverbs_prepositions(sentence):
    # Tokenize the sentence into words
    words = word_tokenize(sentence)
    
    # Perform part-of-speech tagging
    tagged_words = pos_tag(words)
    
    # Filter out adjectives, verbs, adverbs, and prepositions
    filtered_words = [word for word, tag in tagged_words if tag not in ['JJ', 'JJR', 'JJS', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'RB', 'RBR', 'RBS', 'IN']]
    
    # Join the filtered words back into a sentence
    filtered_sentence = ' '.join(filtered_words)
    
    return filtered_sentence

# %%
import re

def filter_ingredients(recipe):
    ingredients = []
    # keep only the ingedient names
    for ingredient in recipe:
        # make everything lowercase
        ingredient = ingredient.lower()
        ingredient = ingredient.split(' ')
        ingredient = [word for word in ingredient if not word.isdigit()]
        ingredient = [word for word in ingredient if not word=='teaspoon']
        ingredient = [word for word in ingredient if not word=='teaspoons']
        ingredient = [word for word in ingredient if not word=='tablespoon']
        ingredient = [word for word in ingredient if not word=='tablespoons']
        ingredient = [word for word in ingredient if not word=='cup']
        ingredient = [word for word in ingredient if not word=='cups']
        ingredient = [word for word in ingredient if not word=='pound']
        ingredient = [word for word in ingredient if not word=='pounds']
        ingredient = [word for word in ingredient if not word=='gram']
        ingredient = [word for word in ingredient if not word=='grams']
        ingredient = [word for word in ingredient if not word=='g']
        ingredient = [word for word in ingredient if not word=='kg']
        ingredient = [word for word in ingredient if not word=='kgs']
        ingredient = [word for word in ingredient if not word=='ml']
        ingredient = [word for word in ingredient if not word=='ltr']
        ingredient = [word for word in ingredient if not word=='ltrs']
        ingredient = [word for word in ingredient if not word=='liter']
        ingredient = [word for word in ingredient if not word=='liters']
        ingredient = [word for word in ingredient if not word=='l']
        ingredient = [word for word in ingredient if not word=='tbsp']
        ingredient = [word for word in ingredient if not word=='tbsps']
        ingredient = [word for word in ingredient if not word=='tsp']
        ingredient = [word for word in ingredient if not word=='tsps']
        ingredient = ' '.join(ingredient)
        if 'to taste' in ingredient:
            ingredient = ingredient.replace('to taste','')
        if 'as per taste' in ingredient:
            ingredient = ingredient.replace('as per taste','')
        # Remove punctuation marks and digits
        ingredient = re.sub(r'[^\w\s]+|\d+', '', ingredient)
        # Remove extra whitespaces between words
        ingredient = re.sub(r'\s+', ' ', ingredient).strip()
        # Remove adjectives, verbs, adverbs, and prepositions
        ingredient = remove_adjectives_verbs_adverbs_prepositions(ingredient)
        ingredients.append(ingredient)

            
    return ingredients
# print(df1['TranslatedIngredients'][1])
# print(filter_ingredients(df1['TranslatedIngredients'][1]))
for index, data in df1['TranslatedIngredients'].iteritems():
    data=filter_ingredients(data)
    # print(data)
    df1.at[index, 'TranslatedIngredients'] = data
    # print(df1['TranslatedIngredients'][index])
# print(df1['TranslatedIngredients'][1])
# print(filter_ingredients(df1['TranslatedIngredients'][1]))

# %% [markdown]
# # EDA

# %%
# eda on ingredients
ingred_count = {}
for index, data in df1['TranslatedIngredients'].iteritems():
    for d in data:
        if d in ingred_count:
            ingred_count[d] += 1
        else:
            ingred_count[d] = 1

# %%
# sort in descending order according to the count
ingred_count = {k: v for k, v in sorted(ingred_count.items(), key=lambda item: item[1], reverse=True)}
ingred_count.pop('')
ingred_count
# Out:
# {'salt': 3913,
#  'chillies': 1592,
#  'cloves': 1518,
#  'powder haldi': 1512,
#  'oil': 1359,
#  'onion': 1353,
#  'chilli powder': 1313,
#  'cumin seeds jeera': 1052,
#  'water': 933,
#  'mustard seeds': 916,
#  'sugar': 887,
#  'inch ginger': 857,
#  'ghee': 706,
#  'garam masala powder': 648,
#  'coconut': 638,
#  'chilli': 634,
#  'pepper powder': 617,
#  'lemon juice': 586,
#  'sprig curry leaves': 574,
#  'coriander powder dhania': 548,
#  'milk': 530,
#  'powder': 506,
#  'butter': 505,
#  'cumin powder jeera': 503,
#  'coriander dhania': 483,
#  'virgin oil': 477,
#  'tomato': 431,
#  'asafoetida hing': 427,
#  'curd dahi yogurt': 425,
#  'tomatoes': 418,
#  'all flour maida': 383,
#  'wheat flour': 375,
#  'onions': 361,
#  'bell capsicum': 358,
#  'jaggery': 347,
#  'peppercorns': 344,
#  'dal split': 342,
#  'cardamom elaichi podsseeds': 335,
#  'inch cinnamon stick dalchini': 320,
#  'ginger paste': 304,
#  'sprig coriander dhania': 267,
#  'flour besan': 266,
# ...

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
stop_words = set(stopwords.words('english'))
stop_words.add('taste')
stop_words.add('tastes')
stop_words.add('a')
stop_words.add('an')
stop_words.add('the')
stop_words.add('as')
stop_words.add('per')
stop_words.add('to')
stop_words.add('pinch')
stop_words.add('pinches')
stop_words.add('cup')
ps = PorterStemmer()
def cleaned_key(sen):
    sen = sen.split(' ')
    for i in sen:
        if i in stop_words:
            sen.remove(i)
    sen = [ps.stem(word) for word in sen]
    sen = ' '.join(sen)
    # print(sen)
    return sen
# print(stop_words)

# %%
ingred_count
# Out:
# {'salt': 3913,
#  'chillies': 1592,
#  'cloves': 1518,
#  'powder haldi': 1512,
#  'oil': 1359,
#  'onion': 1353,
#  'chilli powder': 1313,
#  'cumin seeds jeera': 1052,
#  'water': 933,
#  'mustard seeds': 916,
#  'sugar': 887,
#  'inch ginger': 857,
#  'ghee': 706,
#  'garam masala powder': 648,
#  'coconut': 638,
#  'chilli': 634,
#  'pepper powder': 617,
#  'lemon juice': 586,
#  'sprig curry leaves': 574,
#  'coriander powder dhania': 548,
#  'milk': 530,
#  'powder': 506,
#  'butter': 505,
#  'cumin powder jeera': 503,
#  'coriander dhania': 483,
#  'virgin oil': 477,
#  'tomato': 431,
#  'asafoetida hing': 427,
#  'curd dahi yogurt': 425,
#  'tomatoes': 418,
#  'all flour maida': 383,
#  'wheat flour': 375,
#  'onions': 361,
#  'bell capsicum': 358,
#  'jaggery': 347,
#  'peppercorns': 344,
#  'dal split': 342,
#  'cardamom elaichi podsseeds': 335,
#  'inch cinnamon stick dalchini': 320,
#  'ginger paste': 304,
#  'sprig coriander dhania': 267,
#  'flour besan': 266,
# ...

# %%
# cleaned_key('salt')

# %%
# remove stopwords and stem the keys in the dictionary to check if they are same 
# if they are same then merge the keys by summing their values
import copy
ingred_count_lower=copy.deepcopy(ingred_count)
# make all the keys in ingred_count lowercase
for x in ingred_count:
    ingred_count_lower[x.lower()] = ingred_count_lower.pop(x)
ingred_count_copy = copy.deepcopy(ingred_count_lower)

for key in ingred_count:
    key=key.lower()
    key1=remove_adjectives_verbs_adverbs_prepositions(key)
    new_key = cleaned_key(key1)
    if new_key in ingred_count_copy and new_key!=key:
        ingred_count_copy[new_key] += ingred_count_copy[key]
        ingred_count_copy.pop(key)
    elif new_key!=key:
        ingred_count_copy[new_key] = ingred_count_copy[key]
        ingred_count_copy.pop(key)
# sort in descending order according to the count
ingred_count_copy = {k: v for k, v in sorted(ingred_count_copy.items(), key=lambda item: item[1], reverse=True)}
ingred_count_copy.pop('')
ingred_count_copy
# Out:
# {'salt': 4134,
#  'chilli': 2306,
#  'oil': 1757,
#  'onion': 1746,
#  'clove': 1554,
#  'powder haldi': 1538,
#  'chilli powder': 1321,
#  'cumin seed jeera': 1059,
#  'water': 983,
#  'mustard seed': 919,
#  'sugar': 914,
#  'tomato': 880,
#  'inch ginger': 875,
#  'ghee': 724,
#  'garam masala powder': 650,
#  'coconut': 648,
#  'pepper powder': 621,
#  'asafoetida hing': 607,
#  'lemon juic': 588,
#  'sprig curri leav': 575,
#  'coriand powder dhania': 549,
#  'milk': 545,
#  'butter': 525,
#  'coriand dhania': 518,
#  'powder': 517,
#  'cumin powder jeera': 509,
#  'virgin oil': 486,
#  'curd dahi yogurt': 427,
#  'maida': 386,
#  'bell capsicum': 380,
#  'wheat flour': 377,
#  'peppercorn': 351,
#  'jaggeri': 349,
#  'dal split': 342,
#  'egg': 341,
#  'cardamom elaichi podsse': 339,
#  'inch cinnamon stick dalchini': 320,
#  'ginger past': 305,
#  'sprig coriand dhania': 276,
#  'flour besan': 266,
#  'cardamom powder elaichi': 261,
#  'ginger': 256,
#  'fennel seed': 256,
# ...

# %%
# set threshold 
thresh=846
# keys with count higher than threshold put in a new list
ingred_count_thresh = {}
for key in ingred_count_copy:
    if ingred_count_copy[key] > thresh:
        ingred_count_thresh[key] = ingred_count_copy[key]
common_ingred=list(ingred_count_thresh.keys())
common_ingred
# Out:
# ['salt',
#  'chilli',
#  'oil',
#  'onion',
#  'clove',
#  'powder haldi',
#  'chilli powder',
#  'cumin seed jeera',
#  'water',
#  'mustard seed',
#  'sugar',
#  'tomato',
#  'inch ginger']

# %% [markdown]
# #### Visualizations

# %%
# plot graph for ingred_count 
import matplotlib.pyplot as plt
plt.figure(figsize=(400,200))
plt.bar(list(ingred_count_copy.keys()), list(ingred_count_copy.values()))
plt.xticks(rotation=90)
plt.show()
# save the graph
# plt.savefig('ingred_count1.png')

# %%
# plot graph for ingred_count for first 150 values
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.bar(list(ingred_count_copy.keys())[:150], list(ingred_count_copy.values())[:150])
plt.xticks(rotation=90)
plt.show()
# save the graph
# plt.savefig('ingred_count2.png')

# %%
# assign idf scores to each ingredient where N= 6258 (total number of recipes)
import math
ingred_idf = {}
for ingred in ingred_count_copy:
    ingred_idf[ingred] = math.log(6258/ingred_count_copy[ingred])

# %%
# plot graph for ingred_idf
import matplotlib.pyplot as plt
plt.figure(figsize=(400,200))
plt.bar(list(ingred_idf.keys()), list(ingred_idf.values()))
plt.xticks(rotation=90)
plt.show()
# save the graph
plt.savefig('ingred_idf.png')

# %%
df1['TranslatedIngredients'][1]

# %% [markdown]
# # Recipe

# %%
import pandas as pd
import re
df1 = pd.read_csv('Working_file2.csv')

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

def remove_adjectives_verbs_adverbs_prepositions(sentence):
    # Tokenize the sentence into words
    words = word_tokenize(sentence)
    
    # Perform part-of-speech tagging
    tagged_words = pos_tag(words)
    
    # Filter out adjectives, verbs, adverbs, and prepositions
    filtered_words = [word for word, tag in tagged_words if tag not in ['JJ', 'JJR', 'JJS', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'RB', 'RBR', 'RBS', 'IN']]
    
    # Join the filtered words back into a sentence
    filtered_sentence = ' '.join(filtered_words)
    
    return filtered_sentence

# %%
import enchant
dictionary = enchant.Dict("en_US")
dictionary.add('dal')
dictionary.add('roti')
dictionary.add('rasam')
dictionary.add('dosa')
dictionary.add('idli')
dictionary.add('chutney')
dictionary.check('biryani')
def check_english_words(sentence):
    words = sentence.split()
    non_english_words = []
    
    for word in words:
        if not dictionary.check(word):
            non_english_words.append(word)
    
    return non_english_words

# %%
def keep_after_hyphen(sentence):
    parts = sentence.split('-')
    if(len(parts) == 1):
        parts = sentence.split('(')
    # remove punctuation marks from the two parts
    parts = [re.sub(r'[^\w\s]+', '', part) for part in parts]
    if len(parts) > 1:
        if(check_english_words(parts[0]) == []):
            return parts[0]
        else:
            return parts[1]        
    else:
        return sentence

# %%
def cleanRecipe(recipe):
    # make everything lowercase
    recipe = recipe.lower()
    recipe = keep_after_hyphen(recipe)
    # Remove punctuation marks and digits
    recipe = re.sub(r'[^\w\s]+|\d+', '', recipe)
    # Remove extra whitespaces between words
    recipe = re.sub(r'\s+', ' ', recipe).strip()
    # remove the occurrence of the word recipe
    recipe = recipe.replace('asfoitida','asafoetida ')
    recipe = recipe.replace('recipe', '')
    recipe = recipe.replace('recipes', '')
    recipe = recipe.replace('breakfast', '')
    recipe = recipe.replace('lunch', '')
    recipe = recipe.replace('dinner', '')
    recipe = recipe.replace('snack', '')
    recipe = recipe.replace('snacks', '')
    recipe = recipe.replace('dessert', '')
    recipe = recipe.replace('desserts', '')
    recipe = recipe.replace('appetizer', '')
    recipe = recipe.replace('appetizers', '')
    recipe = recipe.replace('side dish', '')
    recipe = recipe.replace('side dishes', '')
    recipe = recipe.replace('main dish', '')
    recipe = recipe.replace('main dishes', '')
    recipe = recipe.replace('style', '')
    recipe = recipe.replace('hindi', '')
    # Remove adjectives, verbs, adverbs, and prepositions
    recipe = remove_adjectives_verbs_adverbs_prepositions(recipe)
    return recipe
# cleanRecipe(df1['TranslatedRecipeName'][13])

# %%
# import nutrient_val
# print(nutrient_val.get_nutrient_dic('rice vermicelli'))

# %%
# Make a new columns in df1 with all values as None
# df1['Nutrients'] = None

# %% [markdown]
# ## WebScrape

# %%
import nutrient_val
import sys
import json
# nutrient_dic={}
for index, data in df1['TranslatedRecipeName'][500:1000].iteritems():
    data=cleanRecipe(data)
    # print(data)
    # print(data)
    # df1.at[index, 'TranslatedRecipeName'] = data
    # print(df1['TranslatedRecipeName'][index])
    if(data!='' or data!=' '):
        nut_val=nutrient_val.get_nutrient_dic(data)
        if(nut_val!=None):
            df1.at[index, 'Nutrients'] = nut_val
        else:
            df1.at[index, 'Nutrients'] = None
    # if(sys.getsizeof(nutrient_dic)>2 * 1024 * 1024):
    #     # append to a file
    #     with open('nutrient_dica3.txt', 'a') as f:
    #         f.write(json.dumps(nutrient_dic))
    #     nutrient_dic={}
        
    # print(nutrient_dic)
    # break

# %%
df1
# Out:
#                                    TranslatedRecipeName  \
# 0                                  Masala Karela Recipe
# 1                            Spicy Tomato Rice (Recipe)
# 2     Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3     Gongura Chicken Curry Recipe - Andhra Style Go...
# 4     Andhra Style Alam Pachadi Recipe - Adrak Chutn...
# ...                                                 ...
# 6234                         Saffron Paneer Peda Recipe
# 6235  Italian Arancini Rice Balls Recipe With Delici...
# 6236        Quinoa Phirnee Recipe (Quinoa Milk Pudding)
# 6237      Ullikadala Pulusu Recipe | Spring Onion Curry
# 6238  Kashmiri Style Kokur Yakhni Recipe-Chicken Coo...
#
#                                   TranslatedIngredients  PrepTimeInMins  \
# 0                               karela,ram flour,amchur              15
# 1     rice,bc belle bhat powder,chickpea lentils,whi...               5
# 2     white urad dal,hee,spricurry leaves,lemon juic...              20
# ...

# %%
# Write df1 to a csv file
df1.to_csv('Working_file3.csv', index=False)

# %% [markdown]
# # Combinations

# %%
import pandas as pd
import re
df1=pd.read_csv('Working_file4.csv')
# drop a column Instructions
df1.drop('Instructions', axis=1, inplace=True)
# check if translatedinstructions is english otherwise drop that row
for index, data in df1['TranslatedInstructions'].iteritems():
    for d in data:
        if(is_english(d)==False):
            df1.drop(index,inplace=True)
            break

# %%
df1
# Out:
#                                    TranslatedRecipeName  \
# 0                                  Masala Karela Recipe
# 1                            Spicy Tomato Rice (Recipe)
# 2     Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3     Gongura Chicken Curry Recipe - Andhra Style Go...
# 4     Andhra Style Alam Pachadi Recipe - Adrak Chutn...
# ...                                                 ...
# 6234                         Saffron Paneer Peda Recipe
# 6235  Italian Arancini Rice Balls Recipe With Delici...
# 6236        Quinoa Phirnee Recipe (Quinoa Milk Pudding)
# 6237      Ullikadala Pulusu Recipe | Spring Onion Curry
# 6238  Kashmiri Style Kokur Yakhni Recipe-Chicken Coo...
#
#                                   TranslatedIngredients  PrepTimeInMins  \
# 0                              karela,gram flour,amchur              15
# 1     rice,bc belle bhat powder,chickpea lentils,whi...               5
# 2     white urad dal,sprig curry leaves,lemon juice,...              20
# ...

# %%
# write df1 to working_file5.csv
df1.to_csv('Working_file5.csv', index=False)

# %%
df1['TranslatedInstructions']
# Out:
# 0       To begin making the Masala Karela Recipe,de-se...
# 1       To make tomato puliogere, first cut the tomato...
# 2       To begin making the Ragi Vermicelli Recipe, fi...
# 3       To begin making Gongura Chicken Curry Recipe f...
# 4       To make Andhra Style Alam Pachadi, first heat ...
#                               ...
# 6234    To begin making the Saffron Paneer Peda recipe...
# 6235    To begin making the Italian Arancini Rice Ball...
# 6236    To begin making Quinoa Phirnee Recipe, place a...
# 6237    To begin making Ullikadala Pulusu Recipe | Spr...
# 6238    To begin making the Kashmiri Kokur Yakhni reci...
# Name: TranslatedInstructions, Length: 5033, dtype: object

# %%
combinations=[]
for index,data in df1['TranslatedInstructions'].iteritems():
    data= data.strip()
    # Remove extra whitespaces between words
    data = re.sub(r'\s+', ' ', data)
    # Find the index of the second last period or exclamation mark
    # Find all occurrences of periods and exclamation marks
    c=0
    for i in range(len(data)-1,-1,-1):
        if(data[i]=='!' or data[i]=='.'):
            c+=1
        if(c==2):
            combinations.append((data[i+1:]).strip())
            break

# %%
combinations[0]
# Out:
# 'Serve Masala Karela along with Panchmel Dal and Phulka for a weekday meal with your family.'

# %%
dontstartwith=['Serve','Prepare','Check','Enjoy','Add','cup',]

# %%
import nltk

def combine_proper_nouns(sentence):
    tagged_words = nltk.pos_tag(nltk.word_tokenize(sentence))
    proper_nouns = []
    combined_proper_nouns = []

    for word, tag in tagged_words:
        # print(word,tag)
        if (word not in dontstartwith) and (tag == 'NNP' or tag == 'NNPS') :  # Check if the word is a proper noun
            proper_nouns.append(word)
        else:
            if proper_nouns:
                combined_proper_nouns.append(' '.join(proper_nouns))
                proper_nouns = []

    if proper_nouns:  # Handle proper nouns at the end of the sentence
        combined_proper_nouns.append(' '.join(proper_nouns))

    return combined_proper_nouns

# Example usage
# sentence = "John Smith is from New York City and works at Google."
# result = combine_proper_nouns(sentence)
# print(result)

# %%
import nltk

def combine_nouns(sentence):
    tagged_words = nltk.pos_tag(nltk.word_tokenize(sentence))
    nouns = []
    combined_nouns = []

    for word, tag in tagged_words:
        if word not in dontstartwith and tag.startswith('NN'):  # Check if the word is a noun
            nouns.append(word)
        else:
            if nouns:
                combined_nouns.append(' '.join(nouns))
                nouns = []

    if nouns:  # Handle nouns at the end of the sentence
        combined_nouns.append(' '.join(nouns))

    return combined_nouns

# Example usage
# sentence = "The cat is chasing the mouse in the garden."
# result = combine_nouns(sentence)
# print(result)

# %%
combinations[0:20]
# Out:
# ['Serve Masala Karela along with Panchmel Dal and Phulka for a weekday meal with your family.',
#  'Serve tomato puliogre with tomato cucumber raita and papad for dinner.',
#  'Mix well and serve along with Coconut Chutney and a hot cup of coffee or tea for a wholesome breakfast.',
#  'Serve Gongura Chicken with Ghee Rice Recipe | Neychoru , Tomato Onion Cucumber Raita Recipe and a Semiya Payasam for a delicious weekend lunch.',
#  'Serve Andhra Style Alam Pachadi with Ghee Roast Dosa and Kirai Sambar for breakfast.',
#  'Add in the tadka over it and Serve the Pudina Khara Pongal Recipe along with Kathirikai Gothsu Recipe (Spicy and Tangy Eggplant Curry)and South Indian Coconut Chutney for a relaxed weekend breakfast.',
#  'Serve the Udupi Style Ash Gourd Coconut Curry Recipe along with steamed rice, Elai Vadam and Pisarna Manga for lunch.',
# ...

# %%
for i in combinations:
    # print(i)
    pn=combine_proper_nouns(i)
    if(len(pn)>0):
        print(pn)
    else:
        print(combine_nouns(i))
# Out:
# ['Masala Karela', 'Panchmel Dal', 'Phulka']
# ['tomato puliogre', 'cucumber raita', 'papad', 'dinner']
# ['Mix', 'Coconut Chutney']
# ['Gongura Chicken', 'Ghee Rice Recipe | Neychoru', 'Tomato Onion Cucumber Raita Recipe', 'Semiya Payasam']
# ['Andhra Style Alam Pachadi', 'Ghee Roast Dosa', 'Kirai Sambar']
# ['Add', 'Pudina Khara Pongal Recipe', 'Kathirikai Gothsu Recipe', 'Spicy', 'Tangy Eggplant Curry', 'South', 'Coconut Chutney']
# ['Udupi Style Ash Gourd Coconut Curry Recipe', 'Elai Vadam', 'Pisarna Manga']
# ['Black Bean Burrito', 'Green Apple', 'Radish', 'Pepper Salad', 'Carrot Pineapple Orange Juice Recipe']
# ['Spicy Crunchy Masala Idli Recipe']
# ['Cabbage', 'Chutney', 'Vegetable Sambar', 'Rice']
# ['Andhra Style Ingavu Chaaru Recipe', 'Gorikayi Palya Recipe']
# ['Sauf Aloo', 'Amritsari Dal', 'Whole Wheat', 'Paratha']
# ['South']
# ['Hariyali Egg Curry', 'Malabar Parotta', 'Whole Wheat Lachha Paratha', 'Burani Raita']
# ['Garlic Dal']
# ...

# %% [markdown]
# ## Recipes and their non common ingredients

# %%
sentence='Serve the Veg Chili Cheese Burgers Recipe along with baby potato stir fry and Mango Iced Tea Recipe to make it a complete meal.'
words = word_tokenize(sentence)
    
# Perform part-of-speech tagging
tagged_words = pos_tag(words)
tagged_words
# Out:
# [('Serve', 'VB'),
#  ('the', 'DT'),
#  ('Veg', 'NNP'),
#  ('Chili', 'NNP'),
#  ('Cheese', 'NNP'),
#  ('Burgers', 'NNP'),
#  ('Recipe', 'NNP'),
#  ('along', 'IN'),
#  ('with', 'IN'),
#  ('baby', 'NN'),
#  ('potato', 'NN'),
#  ('stir', 'NN'),
#  ('fry', 'NN'),
#  ('and', 'CC'),
#  ('Mango', 'NNP'),
#  ('Iced', 'NNP'),
#  ('Tea', 'NNP'),
#  ('Recipe', 'NNP'),
#  ('to', 'TO'),
#  ('make', 'VB'),
#  ('it', 'PRP'),
#  ('a', 'DT'),
#  ('complete', 'JJ'),
#  ('meal', 'NN'),
#  ('.', '.')]

# %%
# read csv
# df=pd.read_csv('Working_file3.csv')
# df1=pd.read_csv('Ingredients_pre\\cleaned_data_final2.csv')
# make df[TranslatedIngredients] = df1[TranslatedIngredients]
# df['TranslatedIngredients'] = df1['TranslatedIngredients']
df
# Out:
#                                    TranslatedRecipeName  \
# 0                                  Masala Karela Recipe
# 1                            Spicy Tomato Rice (Recipe)
# 2     Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3     Gongura Chicken Curry Recipe - Andhra Style Go...
# 4     Andhra Style Alam Pachadi Recipe - Adrak Chutn...
# ...                                                 ...
# 6234                         Saffron Paneer Peda Recipe
# 6235  Italian Arancini Rice Balls Recipe With Delici...
# 6236        Quinoa Phirnee Recipe (Quinoa Milk Pudding)
# 6237      Ullikadala Pulusu Recipe | Spring Onion Curry
# 6238  Kashmiri Style Kokur Yakhni Recipe-Chicken Coo...
#
#                                   TranslatedIngredients  PrepTimeInMins  \
# 0                              karela,gram flour,amchur              15
# 1     rice,bc belle bhat powder,chickpea lentils,whi...               5
# 2     white urad dal,sprig curry leaves,lemon juice,...              20
# ...

# %%
# write df to working_file4
df.to_csv('Working_file4.csv', index=False)

# %%
# print TranslatedRecipe Name and TranslatedIngredients
for index, data in df['TranslatedRecipeName'].iteritems():
    print(data,end=': ')
    print(df['TranslatedIngredients'][index])
# Out:
# Masala Karela Recipe: karela,gram flour,amchur
# Spicy Tomato Rice (Recipe): rice,bc belle bhat powder,chickpea lentils,white urad dal,mustard,cashew,oil
# Ragi Semiya Upma Recipe - Ragi Millet Vermicelli Breakfast: white urad dal,sprig curry leaves,lemon juice,rice vermicelli noodles,carrots,green peas
# Gongura Chicken Curry Recipe - Andhra Style Gongura Chicken: chicken,garam masala powder,sesame,methi seeds,fennel seeds,sesame,sorrel leaves
# Andhra Style Alam Pachadi Recipe - Adrak Chutney (Recipe): chana dal,white urad dal,red chillies,coriander seeds,inches ginger,mustard,oil,sprig curry
# Pudina Khara Pongal Recipe (Rice and Lentils Cooked With Mint Leaves & Mild Spices): rice,yellow moong dal,cashew nuts,whole black peppercorns,sprig curry leaves,mint leaves
# Udupi Style Ash Gourd Coconut Curry Recipe: fresh coconut,tamarind water,jaggery,tamarind water,sprig curry leaves,vellai poosanikai,methi seeds,sesame seeds
# ...
